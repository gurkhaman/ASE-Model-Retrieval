# %%
from datasets import load_from_disk
import pandas as pd
from transformers import pipeline
from tqdm import tqdm
import os
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report
import json

# %%
HF_DATASET_DIR = "/workspaces/ASE-Model-Retrieval/data/imagenet/.cache/hf_datasets"
MODELS_CSV_PATH = "/workspaces/ASE-Model-Retrieval/models/model-list.csv"
LABEL_MAP_PATH = "/workspaces/ASE-Model-Retrieval/data/imagenet/label_mapping.json"

# %%
hf_dataset_dict = load_from_disk(HF_DATASET_DIR)
hf_dataset_dict
# Out:
# DatasetDict({
#     subclass_Appenzeller-Ibizan_hound-Scottish_deerhound-West_Highland_white_terrier-baseball: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Sealyham_terrier-bloodhound-dipper-tench-white_wolf: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_German_short_haired_pointer-Leonberg-Maltese-husky-pickup_truck: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_beer_bottle-giant_schnauzer-golden_retriever-tiger-white_wolf: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Norwegian_elkhound-Rhodesian_ridgeback-fire_engine-indigo-toy_terrier: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Irish_terrier-Shetland_sheepdog-dingo-miniature_pinscher-softcoated_wheaten_terrier: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Scottie-golden_retriever-leatherback-miniature_pinscher-mud: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Greater_Swiss_Mountain_dog-Samoyed-goldfinch-groenendael-polar_bear: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Bernese_mountain_dog-Labrador_retriever-papillon-toy_poodle-vulture: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_American_Staffordshire_terrier-Bouvier-Japanese_spaniel-Tibetan_mastiff-Walker_foxhound: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Norfolk_terrier-custard_apple-flat_coated_retriever-leopard-volleyball: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_German_shepherd-Persian-komondor-kuvasz-rooster: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Border_terrier-Irish_setter-cocker_spaniel-coyote-standard_poodle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Bouvier-Hungarian_pointer-jackfruit-leopard-miniature_poodle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Bedlington_terrier-Greater_Swiss_Mountain_dog-Norfolk_terrier-borzoi-indigo: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Appenzeller-box-clumber_spaniel-polar_bear-trolleybus: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Scottish_deerhound-West_Highland_white_terrier-bell_pepper-borzoi-great_white: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Saint_Bernard-Siberian_husky-ambulance-coyote-tennis_ball: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_English_setter-Irish_terrier-Rottweiler-chickadee-dalmatian: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Lhasa-Old_English_sheepdog-Saluki-Staffordshire_bullterrier-white_wolf: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Bouvier-Irish_wolfhound-basset_hound-chow-groenendael: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Norwich_terrier-banana-bloodhound-kite-minivan: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Ibizan_hound-Leonberg-kelpie-loggerhead-scooter: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Blenheim_spaniel-Hungarian_pointer-borzoi-brown_bear-groenendael: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Saint_Bernard-Samoyed-cairn-chow-otter_hound: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Appenzeller-Egyptian-English_foxhound-German_shepherd-Leonberg: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Afghan_hound-West_Highland_white_terrier-coyote-goldfinch-grey_owl: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Greater_Swiss_Mountain_dog-custard_apple-hen-husky-rooster: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Italian_greyhound-Labrador_retriever-Welsh_springer_spaniel-bloodhound-snow_leopard: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Appenzeller-Chesapeake_Bay_retriever-Gordon_setter-Old_English_sheepdog-Persian: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Italian_greyhound-Labrador_retriever-Yorkshire_terrier-stingray-tiger_cat: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Japanese_spaniel-Scottie-fire_engine-golden_retriever-hen: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Great_Dane-Sussex_spaniel-dipper-rugby_ball-whippet: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_English_foxhound-Pekinese-Persian-grey_wolf-indigo: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Kerry_blue_terrier-Saluki-brown_bear-tandem_bicycle-tiger_shark: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_English_foxhound-Rhodesian_ridgeback-goldfish-pickup_truck-police_wagon: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Greater_Swiss_Mountain_dog-Pekinese-beer_glass-groenendael-red_wolf: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass
bottle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Afghan_hound-Egyptian-Lhasa-groenendael-mud: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_German_short_haired_pointer-Labrador_retriever-Mexican_hairless-Sealyham_terrier-magpie: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Shih_Tzu-Tibetan_mastiff-cocker_spaniel-red_wolf-vulture: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_affenpinscher-brambling-cocker_spaniel-giant_schnauzer-standard_schnauzer: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_grey_wolf-miniature_poodle-police_wagon-sign_traffic_light-standard_schnauzer: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_American_Staffordshire_terrier-Pomeranian-beaker-fig-grey_wolf: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_cheetah-papillon-tow_truck-volleyball-wine_bottle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_American_Staffordshire_terrier-English_springer-croquet_ball-finch-mud: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Granny_Smith-Irish_water_spaniel-giant_schnauzer-loggerhead-tractor_trailer: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Brabancon_griffon-Italian_greyhound-chickadee-clumber_spaniel-giant_schnauzer: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Australian_terrier-Dandie_Dinmont_terrier-Maltese-Sealyham_terrier-Siamese: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Irish_wolfhound-Norfolk_terrier-baseball-fire_engine-tandem_bicycle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_EntleBucher-Irish_wolfhound-Norwegian_elkhound-mountain_bike-tandem_bicycle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Japanese_spaniel-Maltese-Yorkshire_terrier-lemon-pug: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Shetland_sheepdog-basenji-coffee_mug-leatherback-lion: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Norwegian_elkhound-Shetland_sheepdog-kelpie-lemon-tiger_cat: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Granny_Smith-goldfinch-grey_wolf-tandem_bicycle-tiger: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Hungarian_pointer-coonhound-lion-strawberry-tandem_bicycle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Rhodesian_ridgeback-Weimaraner-bluetick-fig-grey_owl: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_English_setter-French_bulldog-Ibizan_hound-beaker-cocker_spaniel: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_English_springer-Pomeranian-Tibetan_mastiff-chickadee-finch: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Doberman-Irish_terrier-coyote-indigo-miniature_poodle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_EntleBucher-Persian-basset_hound-junco-lynx: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Irish_setter-Japanese_spaniel-box-chow-mountain_bike: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Cardigan-Italian_greyhound-Lakeland_terrier-fire_engine-goldfinch: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_bald_eagle-jay-scooter-terrapin-tiger_cat: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Pembroke-beer_bottle-malinois-mud-stingray: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Airedale-Great_Dane-Saint_Bernard-giant_schnauzer-otter_hound: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_French_bulldog-affenpinscher-bloodhound-husky-sloth_bear: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Irish_setter-Pembroke-Saluki-Siberian_husky-wirehaired_fox_terrier: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_English_setter-Greater_Swiss_Mountain_dog-briard-indigo-komondor: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Dandie_Dinmont_terrier-EntleBucher-Irish_water_spaniel-grey_wolf-husky: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Siamese-Welsh_springer_spaniel-banana-beagle-giant_schnauzer: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Border_terrier-German_short_haired_pointer-basenji-custard_apple-sloth_bear: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_American_Staffordshire_terrier-black_bear-sign_traffic_light-tow_truck-toy_terrier: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Old_English_sheepdog-Yorkshire_terrier-pickup_truck-redbone-sign_traffic_light: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Sussex_spaniel-bluetick-golden_retriever-indigo-mud: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_beagle-custard_apple-dipper-papillon-water_bottle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_American_Staffordshire_terrier-English_foxhound-basset_hound-lemon-red_wolf: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Cardigan-English_foxhound-English_springer-silky_terrier-water_jug: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Border_collie-basset_hound-fig-lion-robin: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Tibetan_mastiff-goldfish-mountain_bike-tabby-tractor_trailer: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Dandie_Dinmont_terrier-Lakeland_terrier-beagle-goldfinch-whippet: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Brabancon_griffon-English_foxhound-Old_English_sheepdog-goldfish-malinois: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_English_foxhound-Scottie-baseball-giant_schnauzer-minibus: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Rottweiler-affenpinscher-box-chickadee-whippet: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Lhasa-basset_hound-box-boxer-malinois: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_
Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Irish_setter-Italian_greyhound-malamute-miniature_poodle-snow_leopard: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Great_Dane-basset_hound-lion-standard_schnauzer-stingray: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Sussex_spaniel-junco-minibus-standard_poodle-tiger_cat: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Egyptian-Pekinese-hen-schipperke-softcoated_wheaten_terrier: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Norwich_terrier-Shih_Tzu-ambulance-dipper-jay: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Chihuahua-bloodhound-brown_bear-tennis_ball-terrapin: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_American_Staffordshire_terrier-grey_owl-loggerhead-miniature_pinscher-tiger: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Border_terrier-Italian_greyhound-beagle-bulbul-redbone: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Rhodesian_ridgeback-standard_schnauzer-tabby-tiger_shark-water_bottle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Siberian_husky-cheetah-chow-grey_wolf-sports_car: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Ibizan_hound-Labrador_retriever-clumber_spaniel-minibus-stingray: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Irish_wolfhound-Pembroke-bald_eagle-pomegranate-volleyball: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Tibetan_mastiff-cougar-police_wagon-snow_leopard-tench: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Blenheim_spaniel-Weimaraner-West_Highland_white_terrier-beagle-tiger_shark: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Mexican_hairless-Samoyed-golden_retriever-indigo-malamute: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Newfoundland-Samoyed-giant_schnauzer-indigo-lynx: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Kerry_blue_terrier-garbage_truck-goldfish-rooster-taxi: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_EntleBucher-German_shepherd-bluetick-croquet_ball-tench: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Irish_setter-Newfoundland-fig-terrapin-trolleybus: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Irish_terrier-Sealyham_terrier-bell_pepper-borzoi-clumber_spaniel: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_beagle-chow-dipper-great_white-stingray: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Doberman-Scottish_deerhound-beer_bottle-rugby_ball-strawberry: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_beagle-great_white-softcoated_wheaten_terrier-standard_poodle-wine_bottle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Hungarian_pointer-cocker_spaniel-dalmatian-jackfruit-schipperke: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Greater_Swiss_Mountain_dog-Labrador_retriever-Pekinese-banana-terrapin: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Brabancon_griffon-Norfolk_terrier-Samoyed-grey_wolf-jay: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_goldfinch-limousine-miniature_poodle-papillon-sloth_bear: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_EntleBucher-Norfolk_terrier-miniature_pinscher-schipperke-wirehaired_fox_terrier: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Gordon_setter-Mexican_hairless-husky-malinois-tabby: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     subclass_Doberman-Pomeranian-Tibetan_terrier-dalmatian-volleyball: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     superclass_bottle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     superclass_bike: Dataset({
#         features: ['image', 'label'],
#         num_rows: 150
#     })
#     superclass_sign: Dataset({
#         features: ['image', 'label'],
#         num_rows: 100
#     })
#     superclass_bird: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     superclass_dog: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     superclass_fish: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     superclass_vehicle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     superclass_bear: Dataset({
#         features: ['image', 'label'],
#         num_rows: 200
#     })
#     superclass_turtle: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     superclass_fruit: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     superclass_ball: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
#     superclass_cat: Dataset({
#         features: ['image', 'label'],
#         num_rows: 250
#     })
# })

# %%
models_df = pd.read_csv(MODELS_CSV_PATH)
models_df
# Out:
#                                              model-id  \
# 0                timm/mobilenetv3_small_100.lamb_in1k
# 1                               timm/resnet50.a1_in1k
# 2               timm/vit_base_patch16_clip_224.openai
# 3                           timm/inception_v3.tv_in1k
# 4   timm/swinv2_large_window12to16_192to256.ms_in2...
# ..                                                ...
# 95                    timm/focalnet_small_lrf.ms_in1k
# 96                         timm/darknetaa53.c2ns_in1k
# 97           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
# 98                          timm/regnetz_c16.ra3_in1k
# 99                       timm/mobileone_s4.apple_in1k
#
#                                               hf-link  base-model  dataset
# 0   https://huggingface.co/timm/mobilenetv3_small_...         NaN      NaN
# 1        https://huggingface.co/timm/resnet50.a1_in1k         NaN      NaN
# 2   https://huggingface.co/timm/vit_base_patch16_c...         NaN      NaN
# 3    https://huggingface.co/timm/inception_v3.tv_in1k         NaN      NaN
# 4   https://huggingface.co/timm/swinv2_large_windo...         NaN      NaN
# ..                                                ...         ...      ...
# 95  https://huggingface.co/timm/focalnet_small_lrf...         NaN      NaN
# 96  https://huggingface.co/timm/darknetaa53.c2ns_in1k         NaN      NaN
# 97  https://huggingface.co/timm/tiny_vit_21m_384.d...         NaN      NaN
# 98   https://huggingface.co/timm/regnetz_c16.ra3_in1k         NaN      NaN
# 99  https://huggingface.co/timm/mobileone_s4.apple...         NaN      NaN
#
# [100 rows x 4 columns]

# %%
def batch_classification(images, model_id, gpu_id, batch_size=128):
    print(f"Batch classification for {model_id}.")
    classifier = pipeline(model=model_id, device=gpu_id)

    with open(LABEL_MAP_PATH, "r") as f:
        label_map = json.load(f)

    predictions = []

    for img_path, pred in zip(
        images, tqdm(classifier(images, batch_size=batch_size), total=len(images))
    ):
        print(f"Image Path: {img_path}")  # Debugging print
        print(f"Raw Prediction: {pred}")  # Debugging print
        corrected_pred = [
            {"label": label_map.get(p["label"], p["label"]), "score": p["score"]}
            for p in pred
        ]
        predictions.append(
            {"image": os.path.basename(img_path), "prediction": corrected_pred}
        )

    return predictions

# %%
test_images = hf_dataset_dict["subclass_Afghan_hound-Egyptian-Lhasa-groenendael-mud"][
    "image"
]
model_id = "timm/vit_base_patch16_clip_224.openai"

predictions = batch_classification(test_images, model_id, gpu_id=0)
predictions
# Out:
# Batch classification for timm/vit_base_patch16_clip_224.openai.
# Some weights of TimmWrapperModel were not initialized from the model checkpoint at timm/vit_base_patch16_clip_224.openai and are newly initialized: ['timm_model.blocks.0.attn.proj.bias', 'timm_model.blocks.0.attn.proj.weight', 'timm_model.blocks.0.attn.qkv.bias', 'timm_model.blocks.0.attn.qkv.weight', 'timm_model.blocks.0.mlp.fc1.bias', 'timm_model.blocks.0.mlp.fc1.weight', 'timm_model.blocks.0.mlp.fc2.bias', 'timm_model.blocks.0.mlp.fc2.weight', 'timm_model.blocks.0.norm1.bias', 'timm_model.blocks.0.norm1.weight', 'timm_model.blocks.0.norm2.bias', 'timm_model.blocks.0.norm2.weight', 'timm_model.blocks.1.attn.proj.bias', 'timm_model.blocks.1.attn.proj.weight', 'timm_model.blocks.1.attn.qkv.bias', 'timm_model.blocks.1.attn.qkv.weight', 'timm_model.blocks.1.mlp.fc1.bias', 'timm_model.blocks.1.mlp.fc1.weight', 'timm_model.blocks.1.mlp.fc2.bias', 'timm_model.blocks.1.mlp.fc2.weight', 'timm_model.blocks.1.norm1.bias', 'timm_model.blocks.1.norm1.weight', 'timm_model.blocks.1.norm2.bias', 'timm_model.blocks.1.norm2.weight', 'timm_model.blocks.10.attn.proj.bias', 'timm_model.blocks.10.attn.proj.weight', 'timm_model.blocks.10.attn.qkv.bias', 'timm_model.blocks.10.attn.qkv.weight', 'timm_model.blocks.10.mlp.fc1.bias', 'timm_model.blocks.10.mlp.fc1.weight', 'timm_model.blocks.10.mlp.fc2.bias', 'timm_model.blocks.10.mlp.fc2.weight', 'timm_model.blocks.10.norm1.bias', 'timm_model.blocks.10.norm1.weight', 'timm_model.blocks.10.norm2.bias', 'timm_model.blocks.10.norm2.weight', 'timm_model.blocks.11.attn.proj.bias', 'timm_model.blocks.11.attn.proj.weight', 'timm_model.blocks.11.attn.qkv.bias', 'timm_model.blocks.11.attn.qkv.weight', 'timm_model.blocks.11.mlp.fc1.bias', 'timm_model.blocks.11.mlp.fc1.weight', 'timm_model.blocks.11.mlp.fc2.bias', 'timm_model.blocks.11.mlp.fc2.weight', 'timm_model.blocks.11.norm1.bias', 'timm_model.blocks.11.norm1.weight', 'timm_model.blocks.11.norm2.bias', 'timm_model.blocks.11.norm2.weight', 'timm_model.blocks.2.attn.proj.bias', 'timm_model.blocks.2.attn.proj.weight', 'timm_model.blocks.2.attn.qkv.bias', 'timm_model.blocks.2.attn.qkv.weight', 'timm_model.blocks.2.mlp.fc1.bias', 'timm_model.blocks.2.mlp.fc1.weight', 'timm_model.blocks.2.mlp.fc2.bias', 'timm_model.blocks.2.mlp.fc2.weight', 'timm_model.blocks.2.norm1.bias', 'timm_model.blocks.2.norm1.weight', 'timm_model.blocks.2.norm2.bias', 'timm_model.blocks.2.norm2.weight', 'timm_model.blocks.3.attn.proj.bias', 'timm_model.blocks.3.attn.proj.weight', 'timm_model.blocks.3.attn.qkv.bias', 'timm_model.blocks.3.attn.qkv.weight', 'timm_model.blocks.3.mlp.fc1.bias', 'timm_model.blocks.3.mlp.fc1.weight', 'timm_model.blocks.3.mlp.fc2.bias', 'timm_model.blocks.3.mlp.fc2.weight', 'timm_model.blocks.3.norm1.bias', 'timm_model.blocks.3.norm1.weight', 'timm_model.blocks.3.norm2.bias', 'timm_model.blocks.3.norm2.weight', 'timm_model.blocks.4.attn.proj.bias', 'timm_model.blocks.4.attn.proj.weight', 'timm_model.blocks.4.attn.qkv.bias', 'timm_model.blocks.4.attn.qkv.weight', 'timm_model.blocks.4.mlp.fc1.bias', 'timm_model.blocks.4.mlp.fc1.weight', 'timm_model.blocks.4.mlp.fc2.bias', 'timm_model.blocks.4.mlp.fc2.weight', 'timm_model.blocks.4.norm1.bias', 'timm_model.blocks.4.norm1.weight', 'timm_model.blocks.4.norm2.bias', 'timm_model.blocks.4.norm2.weight', 'timm_model.blocks.5.attn.proj.bias', 'timm_model.blocks.5.attn.proj.weight', 'timm_model.blocks.5.attn.qkv.bias', 'timm_model.blocks.5.attn.qkv.weight', 'timm_model.blocks.5.mlp.fc1.bias', 'timm_model.blocks.5.mlp.fc1.weight', 'timm_model.blocks.5.mlp.fc2.bias', 'timm_model.blocks.5.mlp.fc2.
.1076741218566895, 0.5535522699356079, -0.7641361951828003, 0.1870952546596527, -0.4701946973800659, -0.34633252024650574, 0.3235545754432678, 0.6199297308921814, 0.14436838030815125, 0.16076503694057465, 0.17022795975208282, -0.20368552207946777, 0.371925950050354, -0.008166694082319736, -2.4161875247955322, -0.6072255969047546, -0.17946116626262665, -0.9770663976669312, -0.1071203351020813, 0.47324058413505554, 0.42874157428741455, -1.0317081212997437, 1.4011896848678589, 1.6943103075027466, 0.38862496614456177, -1.272839069366455, -0.6812027096748352, 0.5747526288032532, -0.7667275667190552, 0.734724223613739, -2.044938564300537, -0.7017771005630493, -1.3978859186172485, 1.6053694486618042, -0.3548784554004669, -0.35674622654914856, 1.233168601989746, -0.4607125222682953, -0.2521785497665405, 1.7578538656234741, -0.46312054991722107, 1.130500316619873, 0.9785327315330505, 1.5765398740768433, 0.7719444036483765, -0.5858261585235596, -0.124592125415802, -1.750842809677124, 0.47764432430267334, -0.2923677861690521, 0.9212112426757812, 1.2270630598068237, -0.19625456631183624, -0.16925841569900513, 0.7451971173286438, -1.0774390697479248, 0.22890156507492065, -1.2360585927963257, 0.2464350461959839, 0.7225357890129089, 1.1011359691619873, 0.974175751209259, -0.27359727025032043, -0.22455544769763947, -0.9938578009605408, -1.3291698694229126, -0.2710281312465668, 1.3628751039505005, -0.20222575962543488, 0.8460556268692017, -0.17867155373096466, -0.07091192156076431, -1.234450340270996, -0.6759116053581238, -0.5727319121360779, 0.826347827911377, -0.09676611423492432, 0.154854878783226, -0.8548709750175476, 1.397540807723999, 0.3304119110107422, -0 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       1 test_images = hf_dataset_dict["subclass_Afghan_hound-Egyptian-Lhasa-groenendael-mud"][
#       2     "image"
#       3 ]
#       4 model_id = "timm/vit_base_patch16_clip_224.openai"
# ----> 6 predictions = batch_classification(test_images, model_id, gpu_id=0)
#       7 predictions
#
# Cell In[11], line 15, in batch_classification(images, model_id, gpu_id, batch_size)
#      13     print(f"Image Path: {img_path}")  # Debugging print
#      14     print(f"Raw Prediction: {pred}")  # Debugging print
# ---> 15     corrected_pred = [
#      16         {"label": label_map.get(p["label"], p["label"]), "score": p["score"]}
#      17         for p in pred
#      18     ]
#      19     predictions.append(
#      20         {"image": os.path.basename(img_path), "prediction": corrected_pred}
#      21     )
#      23 return predictions
#
# Cell In[11], line 16, in <listcomp>(.0)
#      13     print(f"Image Path: {img_path}")  # Debugging print
#      14     print(f"Raw Prediction: {pred}")  # Debugging print
#      15     corrected_pred = [
# ---> 16         {"label": label_map.get(p["label"], p["label"]), "score": p["score"]}
#      17         for p in pred
#      18     ]
#      19     predictions.append(
#      20         {"image": os.path.basename(img_path), "prediction": corrected_pred}
#      21     )
#      23 return predictions
#
# TypeError: list indices must be integers or slices, not str

# %%
def evaluate_model(predictions, dataset):
    ground_truth = {os.path.basename(item["image"]): item["label"] for item in dataset}
    y_true = []
    y_pred = []
    y_pred_top5 = []

    for entry in predictions:
        img_name = entry["image"]
        if img_name in ground_truth:
            true_label = ground_truth[img_name]
            pred_labels = [pred["label"] for pred in entry["prediction"]]

            y_true.append(true_label)
            y_pred.append(pred_labels[0])
            y_pred_top5.append(pred_labels)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    top1_accuracy = accuracy_score(y_true=y_true, y_pred=y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(
        y_true, y_pred, average="weighted"
    )

    top5_correct = sum(1 for true, preds in zip(y_true, y_pred_top5) if true in preds)
    top5_accuracy = top5_correct / len(y_true)

    class_report = classification_report(y_true, y_pred, output_dict=True)

    return {
        "Top-1 Accuracy": top1_accuracy,
        "Top-5 Accuracy": top5_accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1-score": f1,
        "Classification Report": class_report,
    }

# %%
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

# %%
def process_model(model_id):
    results = []
    for dataset_name, dataset in tqdm(hf_dataset_dict.items(), desc=f"Processing {model_id}", leave=True):
        print(f"Evaluating {model_id} on {dataset_name}")
        predictions = batch_classification(dataset["image"], model_id, gpu_id=0)
        result = evaluate_model(predictions, dataset)
        results_df = pd.DataFrame([{
            "model_id": model_id,
            "dataset": dataset_name,
            **result
        }])

        file_path = f"evaluation_results/{dataset_name}.csv"
        results_df.to_csv(file_path, index=False)
        print(f"Results saved: {file_path}")

    return results

os.makedirs("evaluation_results", exist_ok=True)
models_df["evaluation_results"] = models_df["model-id"].apply(process_model)
log_results = [entry for sublist in models_df["evaluation_results"] for entry in sublist]
results_df = pd.DataFrame(log_results)
results_df.to_csv("model_evaluation_log.csv", index=False)
# Out:
# Processing timm/mobilenetv3_small_100.lamb_in1k:   0%|          | 0/312 [00:00<?, ?it/s]
# Evaluating timm/mobilenetv3_small_100.lamb_in1k on subclass_Appenzeller-Ibizan_hound-Scottish_deerhound-West_Highland_white_terrier-baseball
# Batch classification for timm/mobilenetv3_small_100.lamb_in1k.
# Device set to use cuda:0
# 100%|█████████▉| 249/250 [00:00<00:00, 577325.43it/s]
# Processing timm/mobilenetv3_small_100.lamb_in1k:   0%|          | 1/312 [00:01<06:03,  1.17s/it]
# Results saved: evaluation_results/subclass_Appenzeller-Ibizan_hound-Scottish_deerhound-West_Highland_white_terrier-baseball.csv
# Evaluating timm/mobilenetv3_small_100.lamb_in1k on subclass_Sealyham_terrier-bloodhound-dipper-tench-white_wolf
# Batch classification for timm/mobilenetv3_small_100.lamb_in1k.
# Device set to use cuda:0
# 100%|█████████▉| 249/250 [00:00<00:00, 608614.04it/s]
# Processing timm/mobilenetv3_small_100.lamb_in1k:   1%|          | 2/312 [00:08<24:04,  4.66s/it]
# Results saved: evaluation_results/subclass_Sealyham_terrier-bloodhound-dipper-tench-white_wolf.csv
# Evaluating timm/mobilenetv3_small_100.lamb_in1k on subclass_German_short_haired_pointer-Leonberg-Maltese-husky-pickup_truck
# Batch classification for timm/mobilenetv3_small_100.lamb_in1k.
# Device set to use cuda:0
# 100%|█████████▉| 249/250 [00:00<00:00, 522713.56it/s]
# Processing timm/mobilenetv3_small_100.lamb_in1k:   1%|          | 3/312 [00:10<17:53,  3.48s/it]
# Results saved: evaluation_results/subclass_German_short_haired_pointer-Leonberg-Maltese-husky-pickup_truck.csv
# Evaluating timm/mobilenetv3_small_100.lamb_in1k on subclass_beer_bottle-giant_schnauzer-golden_retriever-tiger-white_wolf
# Batch classification for timm/mobilenetv3_small_100.lamb_in1k.
# Device set to use cuda:0
# 100%|█████████▉| 249/250 [00:00<00:00, 453684.49it/s]
# Processing timm/mobilenetv3_small_100.lamb_in1k:   1%|▏         | 4/312 [00:12<15:13,  2.97s/it]
# Results saved: evaluation_results/subclass_beer_bottle-giant_schnauzer-golden_retriever-tiger-white_wolf.csv
# Evaluating timm/mobilenetv3_small_100.lamb_in1k on subclass_Norwegian_elkhound-Rhodesian_ridgeback-fire_engine-indigo-toy_terrier
# Batch classification for timm/mobilenetv3_small_100.lamb_in1k.
# Device set to use cuda:0
# 100%|█████████▉| 249/250 [00:00<00:00, 494498.91it/s]
# Processing timm/mobilenetv3_small_100.lamb_in1k:   2%|▏         | 5/312 [00:14<13:51,  2.71s/it]
# Results saved: evaluation_results/subclass_Norwegian_elkhound-Rhodesian_ridgeback-fire_engine-indigo-toy_terrier.csv
# Evaluating timm/mobilenetv3_small_100.lamb_in1k on subclass_Irish_terrier-Shetland_sheepdog-dingo-miniature_pinscher-softcoated_wheaten_terrier
# Batch classification for timm/mobilenetv3_small_100.lamb_in1k.
# Device set to use cuda:0
# 100%|█████████▉| 249/250 [00:00<00:00, 582477.24it/s]
# Processing timm/mobilenetv3_small_100.lamb_in1k:   2%|▏         | 6/312 [00:16<12:50,  2.52s/it]
# Results saved: evaluation_results/subclass_Irish_terrier-Shetland_sheepdog-dingo-miniature_pinscher-softcoated_wheaten_terrier.csv
# Evaluating timm/mobilenetv3_small_100.lamb_in1k on subclass_Scottie-golden_retriever-leatherback-miniature_pinscher-mud
# Batch classification for timm/mobilenetv3_small_100.lamb_in1k.
# Device set to use cuda:0
# Processing timm/mobilenetv3_small_100.lamb_in1k:   2%|▏         | 6/312 [00:19<16:14,  3.18s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 20
#      17     return results
#      19 os.makedirs("evaluation_results", exist_ok=True)
# ---> 20 models_df["evaluation_results"] = models_df["model-id"].apply(process_model)
#      21 log_results = [entry for sublist in models_df["evaluation_results"] for entry in sublist]
#      22 results_df = pd.DataFrame(log_results)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[13], line 5, in process_model(model_id)
#       3 for dataset_name, dataset in tqdm(hf_dataset_dict.items(), desc=f"Processing {model_id}", leave=True):
#       4     print(f"Evaluating {model_id} on {dataset_name}")
# ----> 5     predictions = batch_classification(dataset["image"], model_id, gpu_id=0)
#       6     result = evaluate_model(predictions, dataset)
#       7     results_df = pd.DataFrame([{
#       8         "model_id": model_id,
#       9         "dataset": dataset_name,
#      10         **result
#      11     }])
#
# Cell In[9], line 11, in batch_classification(images, model_id, gpu_id, batch_size)
#       6     label_map = json.load(f)
#       8 predictions = []
#      10 for img_path, pred in zip(
# ---> 11     images, tqdm(classifier(images, batch_size=batch_size), total=len(images))
#      12 ):
#      13     corrected_pred = [
#      14         {"label": label_map.get(p["label"], p["label"]), "score": p["score"]}
#      15         for p in pred
#      16     ]
#      17     predictions.append(
#      18         {"image": os.path.basename(img_path), "prediction": corrected_pred}
#      19     )
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/image_classification.py:177, in ImageClassificationPipeline.__call__(self, inputs, **kwargs)
#     175 if inputs is None:
#     176     raise ValueError("Cannot call the image-classification pipeline without an inputs argument!")
# --> 177 return super().__call__(inputs, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/base.py:1349, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1345 if can_use_iterator:
#    1346     final_iterator = self.get_iterator(
#    1347         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1348     )
# -> 1349     outputs = list(final_iterator)
#    1350     return outputs
#    1351 else:
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/pt_utils.py:125, in PipelineIterator.__next__(self)
#     123 # We're out of items within a batch
#     124 item = next(self.iterator)
# --> 125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#     127 if self.loader_batch_size is not None:
#     128     # Try to infer the size of the batch
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/image_classification.py:219, in ImageClassificationPipeline.postprocess(self, model_outputs, function_to_apply, top_k)
#     216 else:
#     217     raise ValueError(f"Unrecognized `function_to_apply` argument: {function_to_apply}")
# --> 219 dict_scores = [
#     220     {"label": self.model.config.id2label[i], "score": score.item()} for i, score in enumerate(scores)
#     221 ]
#     222 dict_scores.sort(key=lambda x: x["score"], reverse=True)
#     223 if top_k is not None:
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/image_classification.py:220, in <listcomp>(.0)
#     216 else:
#     217     raise ValueError(f"Unrecognized `function_to_apply` argument: {function_to_apply}")
#     219 dict_scores = [
# --> 220     {"label": self.model.config.id2label[i], "score": score.item()} for i, score in enumerate(scores)
#     221 ]
#     222 dict_scores.sort(key=lambda x: x["score"], reverse=True)
#     223 if top_k is not None:
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd

# %%
def clean_up_partial_results(model_id):
    eval_results_dir = "/workspaces/ASE-Model-Retrieval/models/evaluation_results"
    for file_name in os.listdir(eval_results_dir):
        file_path = os.path.join(eval_results_dir, file_name)
        if file_name.endswith(".csv"):
            df = pd.read_csv(file_path)
            if "model_id" in df.columns and model_id in df["model_id"].values:
                print(f"Removing previous results for {model_id} in {file_path}")
                df = df[df["model_id"] != model_id]
                df.to_csv(file_path, index=False)
                print(f"Cleaned: {file_path}")

# %%
clean_up_partial_results("timm/mobilenetv2_050.lamb_in1k")
# Out:
# Removing previous results for timm/mobilenetv2_050.lamb_in1k in /workspaces/ASE-Model-Retrieval/models/evaluation_results/subclass_Sealyham_terrier-bloodhound-dipper-tench-white_wolf.csv
# Cleaned: /workspaces/ASE-Model-Retrieval/models/evaluation_results/subclass_Sealyham_terrier-bloodhound-dipper-tench-white_wolf.csv
# Removing previous results for timm/mobilenetv2_050.lamb_in1k in /workspaces/ASE-Model-Retrieval/models/evaluation_results/subclass_Appenzeller-Ibizan_hound-Scottish_deerhound-West_Highland_white_terrier-baseball.csv
# Cleaned: /workspaces/ASE-Model-Retrieval/models/evaluation_results/subclass_Appenzeller-Ibizan_hound-Scottish_deerhound-West_Highland_white_terrier-baseball.csv
# Removing previous results for timm/mobilenetv2_050.lamb_in1k in /workspaces/ASE-Model-Retrieval/models/evaluation_results/subclass_beer_bottle-giant_schnauzer-golden_retriever-tiger-white_wolf.csv
# Cleaned: /workspaces/ASE-Model-Retrieval/models/evaluation_results/subclass_beer_bottle-giant_schnauzer-golden_retriever-tiger-white_wolf.csv
# Removing previous results for timm/mobilenetv2_050.lamb_in1k in /workspaces/ASE-Model-Retrieval/models/evaluation_results/subclass_Norwegian_elkhound-Rhodesian_ridgeback-fire_engine-indigo-toy_terrier.csv
# Cleaned: /workspaces/ASE-Model-Retrieval/models/evaluation_results/subclass_Norwegian_elkhound-Rhodesian_ridgeback-fire_engine-indigo-toy_terrier.csv
# Removing previous results for timm/mobilenetv2_050.lamb_in1k in /workspaces/ASE-Model-Retrieval/models/evaluation_results/subclass_German_short_haired_pointer-Leonberg-Maltese-husky-pickup_truck.csv
# Cleaned: /workspaces/ASE-Model-Retrieval/models/evaluation_results/subclass_German_short_haired_pointer-Leonberg-Maltese-husky-pickup_truck.csv
