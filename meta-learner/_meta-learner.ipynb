# %%
import os
import torch
import pandas as pd

# %%
HF_DATASET_DIR = "/workspaces/ASE-Model-Retrieval/data/imagenet/.cache/hf_datasets"
MODELS_CSV_PATH = "/workspaces/ASE-Model-Retrieval/models/model-list.csv"
META_FEATURES_DIR = (
    "/workspaces/ASE-Model-Retrieval/meta-embedding/.cache/task_embeddings"
)
EVALUATION_RESULTS_DIR = "/workspaces/ASE-Model-Retrieval/data/evaluation_results"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
N_ESTIMATORS = 100
NUM_CLASSES = 93

# %%
def load_meta_features(path):
    all_features = sorted([f for f in os.listdir(path) if f.endswith(".pt")])
    print(f"Found {len(all_features)} meta-feature files.")

    meta_features = torch.stack(
        [
            torch.load(os.path.join(path, feature), map_location=DEVICE).flatten()
            for feature in all_features
        ],
        dim=0,
    )
    return meta_features


meta_features = load_meta_features(META_FEATURES_DIR)
meta_features.shape
# Out:
# Found 312 meta-feature files.
# torch.Size([312, 4608])

# %%
def load_evaluation_data(path):
    all_results = sorted([f for f in os.listdir(path) if f.endswith(".csv")])
    print(f"Found {len(all_results)} meta-feature files.")

    all_results = [
        pd.read_csv(os.path.join(path, result), delimiter=",") for result in all_results
    ]

    return all_results


evaluation_data = load_evaluation_data(EVALUATION_RESULTS_DIR)
evaluation_data
# Out:
# Found 312 meta-feature files.
# [                                             model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Afghan_hound-Egyptian-Lhasa-groenenda...           0.604
#  1   subclass_Afghan_hound-Egyptian-Lhasa-groenenda...           0.764
#  2   subclass_Afghan_hound-Egyptian-Lhasa-groenenda...           0.728
#  3   subclass_Afghan_hound-Egyptian-Lhasa-groenenda...           0.812
#  4   subclass_Afghan_hound-Egyptian-Lhasa-groenenda...           0.720
#  ..                                                ...             ...
#  88  subclass_Afghan_hound-Egyptian-Lhasa-groenenda...           0.828
#  89  subclass_Afghan_hound-Egyptian-Lhasa-groenenda...           0.768
#  90  subclass_Afghan_hound-Egyptian-Lhasa-groenenda...           0.796
#  91  subclass_Afghan_hound-Egyptian-Lhasa-groenenda...           0.768
#  92  subclass_Afghan_hound-Egyptian-Lhasa-groenenda...           0.760
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.880   1.000000   0.604  0.743255
#  1            0.956   1.000000   0.764  0.860438
#  2            0.944   1.000000   0.728  0.833234
#  3            0.988   0.991111   0.812  0.889193
#  4            0.932   0.994444   0.720  0.828348
#  ..             ...        ...     ...       ...
#  88           0.972   0.995745   0.828  0.900137
#  89           0.976   1.000000   0.768  0.864854
#  90           0.980   1.000000   0.796  0.882827
#  91           0.968   1.000000   0.768  0.862899
#  92           0.952   1.000000   0.760  0.857427
#
#                                  Classification Report
#  0   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  1   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  2   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  3   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  4   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  ..                                                ...
#  88  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  89  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  90  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  91  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  92  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Afghan_hound-English_setter-Ibizan_ho...           0.780
#  1   subclass_Afghan_hound-English_setter-Ibizan_ho...           0.868
#  2   subclass_Afghan_hound-English_setter-Ibizan_ho...           0.860
#  3   subclass_Afghan_hound-English_setter-Ibizan_ho...           0.916
#  4   subclass_Afghan_hound-English_setter-Ibizan_ho...           0.828
#  ..                                                ...             ...
#  88  subclass_Afghan_hound-English_setter-Ibizan_ho...           0.900
#  89  subclass_Afghan_hound-English_setter-Ibizan_ho...           0.868
#  90  subclass_Afghan_hound-English_setter-Ibizan_ho...           0.928
#  91  subclass_Afghan_hound-English_setter-Ibizan_ho...           0.892
#  92  subclass_Afghan_hound-English_setter-Ibizan_ho...           0.844
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.928   1.000000   0.780  0.868856
#  1            0.980   1.000000   0.868  0.926319
#  2            0.968   0.995652   0.860  0.918849
#  3            0.996   1.000000   0.916  0.953957
#  4            0.968   1.000000   0.828  0.901768
#  ..             ...        ...     ...       ...
#  88           0.992   1.000000   0.900  0.945451
#  89           0.980   1.000000   0.868  0.926189
#  90           0.988   1.000000   0.928  0.961453
#  91           0.980   1.000000   0.892  0.940769
#  92           0.980   1.000000   0.844  0.911675
#
#                                  Classification Report
#  0   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  1   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  2   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  3   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  4   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  ..                                                ...
#  88  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  89  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  90  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  91  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  92  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Afghan_hound-Ibizan_hound-goldfish-ke...           0.720
#  1   subclass_Afghan_hound-Ibizan_hound-goldfish-ke...           0.848
#  2   subclass_Afghan_hound-Ibizan_hound-goldfish-ke...           0.828
#  3   subclass_Afghan_hound-Ibizan_hound-goldfish-ke...           0.900
#  4   subclass_Afghan_hound-Ibizan_hound-goldfish-ke...           0.832
#  ..                                                ...             ...
#  88  subclass_Afghan_hound-Ibizan_hound-goldfish-ke...           0.888
#  89  subclass_Afghan_hound-Ibizan_hound-goldfish-ke...           0.848
#  90  subclass_Afghan_hound-Ibizan_hound-goldfish-ke...           0.908
#  91  subclass_Afghan_hound-Ibizan_hound-goldfish-ke...           0.856
#  92  subclass_Afghan_hound-Ibizan_hound-goldfish-ke...           0.848
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.916   0.992857   0.720  0.822980
#  1            0.976   1.000000   0.848  0.913163
#  2            0.964   1.000000   0.828  0.900193
#  3            0.996   1.000000   0.900  0.944233
#  4            0.964   0.994444   0.832  0.901843
#  ..             ...        ...     ...       ...
#  88           0.984   1.000000   0.888  0.936382
#  89           0.972   0.988571   0.848  0.908387
#  90           0.992   1.000000   0.908  0.948959
#  91           0.980   1.000000   0.856  0.914387
#  92           0.976   1.000000   0.848  0.913419
#
#                                  Classification Report
#  0   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  1   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  2   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  3   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  4   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  ..                                                ...
#  88  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  89  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  90  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  91  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  92  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Afghan_hound-Irish_terrier-Italian_gr...           0.732
#  1   subclass_Afghan_hound-Irish_terrier-Italian_gr...           0.824
#  2   subclass_Afghan_hound-Irish_terrier-Italian_gr...           0.788
#  3   subclass_Afghan_hound-Irish_terrier-Italian_gr...           0.884
#  4   subclass_Afghan_hound-Irish_terrier-Italian_gr...           0.812
#  ..                                                ...             ...
#  88  subclass_Afghan_hound-Irish_terrier-Italian_gr...           0.856
#  89  subclass_Afghan_hound-Irish_terrier-Italian_gr...           0.852
#  90  subclass_Afghan_hound-Irish_terrier-Italian_gr...           0.876
#  91  subclass_Afghan_hound-Irish_terrier-Italian_gr...           0.856
#  92  subclass_Afghan_hound-Irish_terrier-Italian_gr...           0.876
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.940        1.0   0.732  0.839970
#  1            0.988        1.0   0.824  0.896513
#  2            0.972        1.0   0.788  0.870969
#  3            0.992        1.0   0.884  0.930588
#  4            0.964        1.0   0.812  0.889666
#  ..             ...        ...     ...       ...
#  88           0.988        1.0   0.856  0.913626
#  89           0.980        1.0   0.852  0.914617
#  90           0.988        1.0   0.876  0.927246
#  91           0.976        1.0   0.856  0.917735
#  92           0.984        1.0   0.876  0.929774
#
#                                  Classification Report
#  0   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  1   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  2   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  3   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  4   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  ..                                                ...
#  88  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  89  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  90  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  91  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  92  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Afghan_hound-Siamese-minivan-tiger_ca...           0.628
#  1   subclass_Afghan_hound-Siamese-minivan-tiger_ca...           0.712
#  2   subclass_Afghan_hound-Siamese-minivan-tiger_ca...           0.656
#  3   subclass_Afghan_hound-Siamese-minivan-tiger_ca...           0.764
#  4   subclass_Afghan_hound-Siamese-minivan-tiger_ca...           0.664
#  ..                                                ...             ...
#  88  subclass_Afghan_hound-Siamese-minivan-tiger_ca...           0.728
#  89  subclass_Afghan_hound-Siamese-minivan-tiger_ca...           0.692
#  90  subclass_Afghan_hound-Siamese-minivan-tiger_ca...           0.748
#  91  subclass_Afghan_hound-Siamese-minivan-tiger_ca...           0.752
#  92  subclass_Afghan_hound-Siamese-minivan-tiger_ca...           0.716
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.892        1.0   0.628  0.739177
#  1            0.940        1.0   0.712  0.802199
#  2            0.944        1.0   0.656  0.755309
#  3            0.972        1.0   0.764  0.835683
#  4            0.944        1.0   0.664  0.757612
#  ..             ...        ...     ...       ...
#  88           0.968        1.0   0.728  0.807714
#  89           0.956        1.0   0.692  0.779491
#  90           0.956        1.0   0.748  0.823610
#  91           0.960        1.0   0.752  0.825126
#  92           0.936        1.0   0.716  0.806153
#
#                                  Classification Report
#  0   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  1   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  2   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  3   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  4   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  ..                                                ...
#  88  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  89  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  90  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  91  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  92  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Afghan_hound-Staffordshire_bullterrie...           0.632
#  1   subclass_Afghan_hound-Staffordshire_bullterrie...           0.764
#  2   subclass_Afghan_hound-Staffordshire_bullterrie...           0.744
#  3   subclass_Afghan_hound-Staffordshire_bullterrie...           0.816
#  4   subclass_Afghan_hound-Staffordshire_bullterrie...           0.716
#  ..                                                ...             ...
#  88  subclass_Afghan_hound-Staffordshire_bullterrie...           0.808
#  89  subclass_Afghan_hound-Staffordshire_bullterrie...           0.756
#  90  subclass_Afghan_hound-Staffordshire_bullterrie...           0.808
#  91  subclass_Afghan_hound-Staffordshire_bullterrie...           0.768
#  92  subclass_Afghan_hound-Staffordshire_bullterrie...           0.752
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.892        1.0   0.632  0.767412
#  1            0.936        1.0   0.764  0.861415
#  2            0.940        1.0   0.744  0.848428
#  3            0.964        1.0   0.816  0.896378
#  4            0.928        1.0   0.716  0.828671
#  ..             ...        ...     ...       ...
#  88           0.948        1.0   0.808  0.891208
#  89           0.940        1.0   0.756  0.856202
#  90           0.964        1.0   0.808  0.890439
#  91           0.960        1.0   0.768  0.864179
#  92           0.944        1.0   0.752  0.853111
#
#                                  Classification Report
#  0   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  1   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  2   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  3   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  4   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  ..                                                ...
#  88  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  89  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  90  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  91  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  92  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Afghan_hound-West_Highland_white_terr...           0.840
#  1   subclass_Afghan_hound-West_Highland_white_terr...           0.904
#  2   subclass_Afghan_hound-West_Highland_white_terr...           0.892
#  3   subclass_Afghan_hound-West_Highland_white_terr...           0.936
#  4   subclass_Afghan_hound-West_Highland_white_terr...           0.868
#  ..                                                ...             ...
#  88  subclass_Afghan_hound-West_Highland_white_terr...           0.924
#  89  subclass_Afghan_hound-West_Highland_white_terr...           0.892
#  90  subclass_Afghan_hound-West_Highland_white_terr...           0.936
#  91  subclass_Afghan_hound-West_Highland_white_terr...           0.924
#  92  subclass_Afghan_hound-West_Highland_white_terr...           0.896
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.952        1.0   0.840  0.904001
#  1            0.968        1.0   0.904  0.945408
#  2            0.968        1.0   0.892  0.939744
#  3            0.984        1.0   0.936  0.964013
#  4            0.960        1.0   0.868  0.922572
#  ..             ...        ...     ...       ...
#  88           0.976        1.0   0.924  0.957300
#  89           0.964        1.0   0.892  0.935735
#  90           0.976        1.0   0.936  0.964013
#  91           0.976        1.0   0.924  0.956500
#  92           0.968        1.0   0.896  0.939642
#
#                                  Classification Report
#  0   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  1   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  2   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  3   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  4   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  ..                                                ...
#  88  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  89  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  90  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  91  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  92  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Afghan_hound-cheetah-kite-schipperke-...           0.796
#  1   subclass_Afghan_hound-cheetah-kite-schipperke-...           0.904
#  2   subclass_Afghan_hound-cheetah-kite-schipperke-...           0.888
#  3   subclass_Afghan_hound-cheetah-kite-schipperke-...           0.952
#  4   subclass_Afghan_hound-cheetah-kite-schipperke-...           0.888
#  ..                                                ...             ...
#  88  subclass_Afghan_hound-cheetah-kite-schipperke-...           0.952
#  89  subclass_Afghan_hound-cheetah-kite-schipperke-...           0.912
#  90  subclass_Afghan_hound-cheetah-kite-schipperke-...           0.948
#  91  subclass_Afghan_hound-cheetah-kite-schipperke-...           0.936
#  92  subclass_Afghan_hound-cheetah-kite-schipperke-...           0.920
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.956        1.0   0.796  0.883432
#  1            0.988        1.0   0.904  0.949049
#  2            0.984        1.0   0.888  0.939976
#  3            0.996        1.0   0.952  0.975166
#  4            0.976        1.0   0.888  0.939976
#  ..             ...        ...     ...       ...
#  88           0.992        1.0   0.952  0.975298
#  89           0.984        1.0   0.912  0.953019
#  90           0.992        1.0   0.948  0.973150
#  91           0.988        1.0   0.936  0.966660
#  92           0.988        1.0   0.920  0.957923
#
#                                  Classification Report
#  0   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  1   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  2   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  3   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  4   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  ..                                                ...
#  88  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  89  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  90  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  91  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  92  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Airedale-Australian_terrier-Maltese-r...           0.700
#  1   subclass_Airedale-Australian_terrier-Maltese-r...           0.788
#  2   subclass_Airedale-Australian_terrier-Maltese-r...           0.784
#  3   subclass_Airedale-Australian_terrier-Maltese-r...           0.848
#  4   subclass_Airedale-Australian_terrier-Maltese-r...           0.756
#  ..                                                ...             ...
#  88  subclass_Airedale-Australian_terrier-Maltese-r...           0.816
#  89  subclass_Airedale-Australian_terrier-Maltese-r...           0.780
#  90  subclass_Airedale-Australian_terrier-Maltese-r...           0.820
#  91  subclass_Airedale-Australian_terrier-Maltese-r...           0.804
#  92  subclass_Airedale-Australian_terrier-Maltese-r...           0.800
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.880        1.0   0.700  0.812344
#  1            0.944        1.0   0.788  0.878887
#  2            0.940        1.0   0.784  0.875029
#  3            0.972        1.0   0.848  0.914806
#  4            0.948        1.0   0.756  0.853406
#  ..             ...        ...     ...       ...
#  88           0.964        1.0   0.816  0.895085
#  89           0.944        1.0   0.780  0.871322
#  90           0.960        1.0   0.820  0.897079
#  91           0.952        1.0   0.804  0.885744
#  92           0.952        1.0   0.800  0.885396
#
#                                  Classification Report
#  0   {'Airedale': {'precision': 1.0, 'recall': 0.76...
#  1   {'Airedale': {'precision': 1.0, 'recall': 0.82...
#  2   {'Airedale': {'precision': 1.0, 'recall': 0.82...
#  3   {'Airedale': {'precision': 1.0, 'recall': 0.92...
#  4   {'Airedale': {'precision': 1.0, 'recall': 0.86...
#  ..                                                ...
#  88  {'Airedale': {'precision': 1.0, 'recall': 0.86...
#  89  {'Airedale': {'precision': 1.0, 'recall': 0.88...
#  90  {'Airedale': {'precision': 1.0, 'recall': 0.92...
#  91  {'Airedale': {'precision': 1.0, 'recall': 0.9,...
#  92  {'Airedale': {'precision': 1.0, 'recall': 0.86...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Airedale-Boston_terrier-otter_hound-r...           0.736
#  1   subclass_Airedale-Boston_terrier-otter_hound-r...           0.836
#  2   subclass_Airedale-Boston_terrier-otter_hound-r...           0.816
#  3   subclass_Airedale-Boston_terrier-otter_hound-r...           0.920
#  4   subclass_Airedale-Boston_terrier-otter_hound-r...           0.824
#  ..                                                ...             ...
#  88  subclass_Airedale-Boston_terrier-otter_hound-r...           0.876
#  89  subclass_Airedale-Boston_terrier-otter_hound-r...           0.824
#  90  subclass_Airedale-Boston_terrier-otter_hound-r...           0.900
#  91  subclass_Airedale-Boston_terrier-otter_hound-r...           0.860
#  92  subclass_Airedale-Boston_terrier-otter_hound-r...           0.840
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.888   0.985366   0.736  0.840207
#  1            0.952   0.990698   0.836  0.904281
#  2            0.968   0.982222   0.816  0.889136
#  3            0.976   0.991667   0.920  0.953566
#  4            0.960   0.991111   0.824  0.897386
#  ..             ...        ...     ...       ...
#  88           0.976   0.986566   0.876  0.926491
#  89           0.956   0.995556   0.824  0.899708
#  90           0.976   0.986789   0.900  0.940320
#  91           0.976   0.991489   0.860  0.918475
#  92           0.960   0.986349   0.840  0.904506
#
#                                  Classification Report
#  0   {'Airedale': {'precision': 0.926829268292683, ...
#  1   {'Airedale': {'precision': 0.9534883720930233,...
#  2   {'Airedale': {'precision': 0.9111111111111111,...
#  3   {'Airedale': {'precision': 0.9583333333333334,...
#  4   {'Airedale': {'precision': 0.9555555555555556,...
#  ..                                                ...
#  88  {'Airedale': {'precision': 0.9555555555555556,...
#  89  {'Airedale': {'precision': 0.9777777777777777,...
#  90  {'Airedale': {'precision': 0.9583333333333334,...
#  91  {'Airedale': {'precision': 0.9574468085106383,...
#  92  {'Airedale': {'precision': 0.9555555555555556,...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Airedale-Great_Dane-Saint_Bernard-gia...           0.688
#  1   subclass_Airedale-Great_Dane-Saint_Bernard-gia...           0.848
#  2   subclass_Airedale-Great_Dane-Saint_Bernard-gia...           0.800
#  3   subclass_Airedale-Great_Dane-Saint_Bernard-gia...           0.896
#  4   subclass_Airedale-Great_Dane-Saint_Bernard-gia...           0.832
#  ..                                                ...             ...
#  88  subclass_Airedale-Great_Dane-Saint_Bernard-gia...           0.888
#  89  subclass_Airedale-Great_Dane-Saint_Bernard-gia...           0.848
#  90  subclass_Airedale-Great_Dane-Saint_Bernard-gia...           0.900
#  91  subclass_Airedale-Great_Dane-Saint_Bernard-gia...           0.852
#  92  subclass_Airedale-Great_Dane-Saint_Bernard-gia...           0.860
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.888   0.981018   0.688  0.798969
#  1            0.936   0.990698   0.848  0.912691
#  2            0.948   0.973205   0.800  0.875467
#  3            0.972   0.987585   0.896  0.938527
#  4            0.956   0.991111   0.832  0.902796
#  ..             ...        ...     ...       ...
#  88           0.968   0.986566   0.888  0.933476
#  89           0.960   0.995556   0.848  0.913513
#  90           0.972   0.986789   0.900  0.940460
#  91           0.968   0.991489   0.852  0.914440
#  92           0.972   0.982268   0.860  0.915768
#
#                                  Classification Report
#  0   {'Airedale': {'precision': 0.926829268292683, ...
#  1   {'Airedale': {'precision': 0.9534883720930233,...
#  2   {'Airedale': {'precision': 0.9111111111111111,...
#  3   {'Airedale': {'precision': 0.9583333333333334,...
#  4   {'Airedale': {'precision': 0.9555555555555556,...
#  ..                                                ...
#  88  {'Airedale': {'precision': 0.9555555555555556,...
#  89  {'Airedale': {'precision': 0.9777777777777777,...
#  90  {'Airedale': {'precision': 0.9583333333333334,...
#  91  {'Airedale': {'precision': 0.9574468085106383,...
#  92  {'Airedale': {'precision': 0.9555555555555556,...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_Airedale-giant_schnauzer-magpie-pug-w...           0.796
#  1   subclass_Airedale-giant_schnauzer-magpie-pug-w...           0.892
#  2   subclass_Airedale-giant_schnauzer-magpie-pug-w...           0.876
#  3   subclass_Airedale-giant_schnauzer-magpie-pug-w...           0.952
#  4   subclass_Airedale-giant_schnauzer-magpie-pug-w...           0.892
#  ..                                                ...             ...
#  88  subclass_Airedale-giant_schnauzer-magpie-pug-w...           0.924
#  89  subclass_Airedale-giant_schnauzer-magpie-pug-w...           0.908
#  90  subclass_Airedale-giant_schnauzer-magpie-pug-w...           0.936
#  91  subclass_Airedale-giant_schnauzer-magpie-pug-w...           0.920
#  92  subclass_Airedale-giant_schnauzer-magpie-pug-w...           0.884
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.948   1.000000   0.796  0.883971
#  1            0.972   0.995349   0.892  0.940160
#  2            0.984   0.995349   0.876  0.930818
#  3            0.988   0.995745   0.952  0.973024
#  4            0.976   0.995349   0.892  0.940279
#  ..             ...        ...     ...       ...
#  88           0.988   0.995652   0.924  0.958011
#  89           0.984   0.991634   0.908  0.946940
#  90           0.984   0.995556   0.936  0.964556
#  91           0.984   1.000000   0.920  0.957572
#  92           0.988   1.000000   0.884  0.937412
#
#                                  Classification Report
#  0   {'Airedale': {'precision': 1.0, 'recall': 0.76...
#  1   {'Airedale': {'precision': 1.0, 'recall': 0.82...
#  2   {'Airedale': {'precision': 1.0, 'recall': 0.82...
#  3   {'Airedale': {'precision': 1.0, 'recall': 0.92...
#  4   {'Airedale': {'precision': 1.0, 'recall': 0.86...
#  ..                                                ...
#  88  {'Airedale': {'precision': 1.0, 'recall': 0.86...
#  89  {'Airedale': {'precision': 1.0, 'recall': 0.88...
#  90  {'Airedale': {'precision': 1.0, 'recall': 0.92...
#  91  {'Airedale': {'precision': 1.0, 'recall': 0.9,...
#  92  {'Airedale': {'precision': 1.0, 'recall': 0.86...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_American_Staffordshire_terrier-Border...           0.760
#  1   subclass_American_Staffordshire_terrier-Border...           0.888
#  2   subclass_American_Staffordshire_terrier-Border...           0.892
#  3   subclass_American_Staffordshire_terrier-Border...           0.924
#  4   subclass_American_Staffordshire_terrier-Border...           0.868
#  ..                                                ...             ...
#  88  subclass_American_Staffordshire_terrier-Border...           0.916
#  89  subclass_American_Staffordshire_terrier-Border...           0.900
#  90  subclass_American_Staffordshire_terrier-Border...           0.920
#  91  subclass_American_Staffordshire_terrier-Border...           0.896
#  92  subclass_American_Staffordshire_terrier-Border...           0.888
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.932        1.0   0.760  0.856224
#  1            0.976        1.0   0.888  0.937683
#  2            0.968        1.0   0.892  0.941767
#  3            0.980        1.0   0.924  0.959576
#  4            0.968        1.0   0.868  0.925390
#  ..             ...        ...     ...       ...
#  88           0.984        1.0   0.916  0.954487
#  89           0.972        1.0   0.900  0.945329
#  90           0.984        1.0   0.920  0.956849
#  91           0.980        1.0   0.896  0.942305
#  92           0.980        1.0   0.888  0.938748
#
#                                  Classification Report
#  0   {'African hunting dog, hyena dog, Cape hunting...
#  1   {'American_Staffordshire_terrier': {'precision...
#  2   {'American_Staffordshire_terrier': {'precision...
#  3   {'American_Staffordshire_terrier': {'precision...
#  4   {'American_Staffordshire_terrier': {'precision...
#  ..                                                ...
#  88  {'American_Staffordshire_terrier': {'precision...
#  89  {'American_Staffordshire_terrier': {'precision...
#  90  {'American_Staffordshire_terrier': {'precision...
#  91  {'American_Staffordshire_terrier': {'precision...
#  92  {'American_Staffordshire_terrier': {'precision...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_American_Staffordshire_terrier-Bouvie...           0.700
#  1   subclass_American_Staffordshire_terrier-Bouvie...           0.836
#  2   subclass_American_Staffordshire_terrier-Bouvie...           0.796
#  3   subclass_American_Staffordshire_terrier-Bouvie...           0.884
#  4   subclass_American_Staffordshire_terrier-Bouvie...           0.772
#  ..                                                ...             ...
#  88  subclass_American_Staffordshire_terrier-Bouvie...           0.856
#  89  subclass_American_Staffordshire_terrier-Bouvie...           0.812
#  90  subclass_American_Staffordshire_terrier-Bouvie...           0.848
#  91  subclass_American_Staffordshire_terrier-Bouvie...           0.820
#  92  subclass_American_Staffordshire_terrier-Bouvie...           0.804
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.940   1.000000   0.700  0.816496
#  1            0.968   0.994444   0.836  0.906668
#  2            0.972   0.995000   0.796  0.883308
#  3            0.988   1.000000   0.884  0.937648
#  4            0.952   1.000000   0.772  0.869245
#  ..             ...        ...     ...       ...
#  88           0.988   0.995238   0.856  0.918975
#  89           0.984   1.000000   0.812  0.894271
#  90           0.988   1.000000   0.848  0.915765
#  91           0.980   1.000000   0.820  0.899911
#  92           0.980   1.000000   0.804  0.889859
#
#                                  Classification Report
#  0   {'American_Staffordshire_terrier': {'precision...
#  1   {'American_Staffordshire_terrier': {'precision...
#  2   {'American_Staffordshire_terrier': {'precision...
#  3   {'American_Staffordshire_terrier': {'precision...
#  4   {'Airedale': {'precision': 0.0, 'recall': 0.0,...
#  ..                                                ...
#  88  {'American_Staffordshire_terrier': {'precision...
#  89  {'American_Staffordshire_terrier': {'precision...
#  90  {'American_Staffordshire_terrier': {'precision...
#  91  {'American_Staffordshire_terrier': {'precision...
#  92  {'American_Staffordshire_terrier': {'precision...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_American_Staffordshire_terrier-Englis...           0.552
#  1   subclass_American_Staffordshire_terrier-Englis...           0.636
#  2   subclass_American_Staffordshire_terrier-Englis...           0.648
#  3   subclass_American_Staffordshire_terrier-Englis...           0.724
#  4   subclass_American_Staffordshire_terrier-Englis...           0.644
#  ..                                                ...             ...
#  88  subclass_American_Staffordshire_terrier-Englis...           0.700
#  89  subclass_American_Staffordshire_terrier-Englis...           0.648
#  90  subclass_American_Staffordshire_terrier-Englis...           0.712
#  91  subclass_American_Staffordshire_terrier-Englis...           0.676
#  92  subclass_American_Staffordshire_terrier-Englis...           0.680
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.896   0.982051   0.552  0.686679
#  1            0.932   0.989566   0.636  0.751374
#  2            0.944   0.985476   0.648  0.765056
#  3            0.964   0.990803   0.724  0.821241
#  4            0.932   0.995238   0.644  0.766567
#  ..             ...        ...     ...       ...
#  88           0.960   0.990349   0.700  0.809507
#  89           0.960   0.989859   0.648  0.763369
#  90           0.956   1.000000   0.712  0.812607
#  91           0.944   0.994595   0.676  0.793329
#  92           0.944   0.995556   0.680  0.795804
#
#                                  Classification Report
#  0   {'American_Staffordshire_terrier': {'precision...
#  1   {'American_Staffordshire_terrier': {'precision...
#  2   {'American_Staffordshire_terrier': {'precision...
#  3   {'American_Staffordshire_terrier': {'precision...
#  4   {'American_Staffordshire_terrier': {'precision...
#  ..                                                ...
#  88  {'American_Staffordshire_terrier': {'precision...
#  89  {'American_Staffordshire_terrier': {'precision...
#  90  {'American_Staffordshire_terrier': {'precision...
#  91  {'American_Staffordshire_terrier': {'precision...
#  92  {'American_Staffordshire_terrier': {'precision...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_American_Staffordshire_terrier-Englis...           0.696
#  1   subclass_American_Staffordshire_terrier-Englis...           0.828
#  2   subclass_American_Staffordshire_terrier-Englis...           0.824
#  3   subclass_American_Staffordshire_terrier-Englis...           0.900
#  4   subclass_American_Staffordshire_terrier-Englis...           0.800
#  ..                                                ...             ...
#  88  subclass_American_Staffordshire_terrier-Englis...           0.884
#  89  subclass_American_Staffordshire_terrier-Englis...           0.864
#  90  subclass_American_Staffordshire_terrier-Englis...           0.884
#  91  subclass_American_Staffordshire_terrier-Englis...           0.844
#  92  subclass_American_Staffordshire_terrier-Englis...           0.840
#
#      Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.924        1.0   0.696  0.809798
#  1            0.988        1.0   0.828  0.899192
#  2            0.980        1.0   0.824  0.896982
#  3            0.992        1.0   0.900  0.945069
#  4            0.972        1.0   0.800  0.879906
#  ..             ...        ...     ...       ...
#  88           0.992        1.0   0.884  0.936213
#  89           0.992        1.0   0.864  0.923208
#  90           0.996        1.0   0.884  0.933581
#  91           0.992        1.0   0.844  0.909148
#  92           0.988        1.0   0.840  0.906573
#
#                                  Classification Report
#  0   {'American alligator, Alligator mississipiensi...
#  1   {'American_Staffordshire_terrier': {'precision...
#  2   {'American alligator, Alligator mississipiensi...
#  3   {'American_Staffordshire_terrier': {'precision...
#  4   {'American alligator, Alligator mississipiensi...
#  ..                                                ...
#  88  {'American_Staffordshire_terrier': {'precision...
#  89  {'American_Staffordshire_terrier': {'precision...
#  90  {'American_Staffordshire_terrier': {'precision...
#  91  {'American_Staffordshire_terrier': {'precision...
#  92  {'American alligator, Alligator mississipiensi...
#
#  [93 rows x 8 columns],
#                                               model_id  \
#  0                timm/mobilenetv3_small_100.lamb_in1k
#  1                               timm/resnet50.a1_in1k
#  2                           timm/inception_v3.tv_in1k
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...
#  4                        timm/efficientnet_b0.ra_in1k
#  ..                                                ...
#  88                    timm/focalnet_small_lrf.ms_in1k
#  89                         timm/darknetaa53.c2ns_in1k
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k
#  91                          timm/regnetz_c16.ra3_in1k
#  92                       timm/mobileone_s4.apple_in1k
#
#                                                dataset  Top-1 Accuracy  \
#  0   subclass_American_Staffordshire_terrier-Hungar...           0.656
#  1   subclass_American_Staffordshire_terrier-Hungar...           0.792
#  2   subclass_American_Staffordshire_terrier-Hungar...           0.788
#  3   subclass_American_Staffordshire_terrier-Hungar...           0.840
#  4   subclass_American_Staffordshire_terrier-Hungar...           0.796
# ...
#  2            0.788           0.964   0.811330   0.788  0.791715
#  3            0.832           0.980   0.847463   0.832  0.829419
#  4            0.792           0.960   0.805621   0.792  0.789483
#  ..             ...             ...        ...     ...       ...
#  88           0.820           0.972   0.820890   0.820  0.814188
#  89           0.804           0.984   0.822832   0.804  0.801314
#  90           0.840           0.980   0.876518   0.840  0.841882
#  91           0.820           0.972   0.831272   0.820  0.817552
#  92           0.820           0.968   0.842483   0.820  0.824115
#
#                                  Classification Report
#  0   {'Angora, Angora rabbit': {'precision': 0.0, '...
#  1   {'Cardigan': {'precision': 0.0, 'recall': 0.0,...
#  2   {'Egyptian': {'precision': 0.7142857142857143,...
#  3   {'Egyptian': {'precision': 0.5909090909090909,...
#  4   {'African grey, African gray, Psittacus eritha...
#  ..                                                ...
#  88  {'Egyptian': {'precision': 0.5909090909090909,...
#  89  {'Border_collie': {'precision': 0.0, 'recall':...
#  90  {'Angora, Angora rabbit': {'precision': 0.0, '...
#  91  {'Angora, Angora rabbit': {'precision': 0.0, '...
#  92  {'Border_collie': {'precision': 0.0, 'recall':...
#
#  [93 rows x 8 columns],
#                                               model_id         dataset  \
#  0                timm/mobilenetv3_small_100.lamb_in1k  superclass_dog
#  1                               timm/resnet50.a1_in1k  superclass_dog
#  2                           timm/inception_v3.tv_in1k  superclass_dog
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...  superclass_dog
#  4                        timm/efficientnet_b0.ra_in1k  superclass_dog
#  ..                                                ...             ...
#  88                    timm/focalnet_small_lrf.ms_in1k  superclass_dog
#  89                         timm/darknetaa53.c2ns_in1k  superclass_dog
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k  superclass_dog
#  91                          timm/regnetz_c16.ra3_in1k  superclass_dog
#  92                       timm/mobileone_s4.apple_in1k  superclass_dog
#
#      Top-1 Accuracy  Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.752           0.904   0.807333   0.752  0.750733
#  1            0.808           0.952   0.853533   0.808  0.809921
#  2            0.808           0.964   0.865000   0.808  0.807968
#  3            0.888           0.980   0.919610   0.888  0.892404
#  4            0.804           0.952   0.864911   0.804  0.811534
#  ..             ...             ...        ...     ...       ...
#  88           0.840           0.980   0.876800   0.840  0.839267
#  89           0.824           0.964   0.870067   0.824  0.822597
#  90           0.868           0.972   0.911276   0.868  0.874011
#  91           0.828           0.968   0.866667   0.828  0.827959
#  92           0.804           0.960   0.851400   0.804  0.804204
#
#                                  Classification Report
#  0   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  1   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  2   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  3   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  4   {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  ..                                                ...
#  88  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  89  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  90  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  91  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#  92  {'Afghan_hound': {'precision': 1.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id          dataset  \
#  0                timm/mobilenetv3_small_100.lamb_in1k  superclass_fish
#  1                               timm/resnet50.a1_in1k  superclass_fish
#  2                           timm/inception_v3.tv_in1k  superclass_fish
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...  superclass_fish
#  4                        timm/efficientnet_b0.ra_in1k  superclass_fish
#  ..                                                ...              ...
#  88                    timm/focalnet_small_lrf.ms_in1k  superclass_fish
#  89                         timm/darknetaa53.c2ns_in1k  superclass_fish
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k  superclass_fish
#  91                          timm/regnetz_c16.ra3_in1k  superclass_fish
#  92                       timm/mobileone_s4.apple_in1k  superclass_fish
#
#      Top-1 Accuracy  Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.776           0.956   0.948909   0.776  0.852675
#  1            0.896           0.976   0.982112   0.896  0.936783
#  2            0.888           0.976   0.986152   0.888  0.934142
#  3            0.956           0.992   0.988000   0.956  0.971461
#  4            0.872           0.976   0.965146   0.872  0.915641
#  ..             ...             ...        ...     ...       ...
#  88           0.924           0.984   0.974978   0.924  0.948440
#  89           0.876           0.964   0.961944   0.876  0.915910
#  90           0.956           0.992   0.988000   0.956  0.971503
#  91           0.928           0.984   0.979455   0.928  0.952587
#  92           0.888           0.972   0.974090   0.888  0.928566
#
#                                  Classification Report
#  0   {'aircraft carrier, carrier, flattop, attack a...
#  1   {'bittern': {'precision': 0.0, 'recall': 0.0, ...
#  2   {'Italian_greyhound': {'precision': 0.0, 'reca...
#  3   {'bittern': {'precision': 0.0, 'recall': 0.0, ...
#  4   {'bittern': {'precision': 0.0, 'recall': 0.0, ...
#  ..                                                ...
#  88  {'bittern': {'precision': 0.0, 'recall': 0.0, ...
#  89  {'anemone fish': {'precision': 0.0, 'recall': ...
#  90  {'bittern': {'precision': 0.0, 'recall': 0.0, ...
#  91  {'bittern': {'precision': 0.0, 'recall': 0.0, ...
#  92  {'anemone fish': {'precision': 0.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id           dataset  \
#  0                timm/mobilenetv3_small_100.lamb_in1k  superclass_fruit
#  1                               timm/resnet50.a1_in1k  superclass_fruit
#  2                           timm/inception_v3.tv_in1k  superclass_fruit
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...  superclass_fruit
#  4                        timm/efficientnet_b0.ra_in1k  superclass_fruit
#  ..                                                ...               ...
#  88                    timm/focalnet_small_lrf.ms_in1k  superclass_fruit
#  89                         timm/darknetaa53.c2ns_in1k  superclass_fruit
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k  superclass_fruit
#  91                          timm/regnetz_c16.ra3_in1k  superclass_fruit
#  92                       timm/mobileone_s4.apple_in1k  superclass_fruit
#
#      Top-1 Accuracy  Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.776           0.956   0.895690   0.776  0.824332
#  1            0.872           0.960   0.940452   0.872  0.898258
#  2            0.840           0.960   0.918327   0.840  0.873511
#  3            0.916           0.996   0.937438   0.916  0.924462
#  4            0.832           0.956   0.925551   0.832  0.872134
#  ..             ...             ...        ...     ...       ...
#  88           0.876           0.988   0.921134   0.876  0.895685
#  89           0.868           0.972   0.930875   0.868  0.893651
#  90           0.912           0.992   0.944833   0.912  0.924738
#  91           0.884           0.964   0.928194   0.884  0.900348
#  92           0.836           0.960   0.903680   0.836  0.862927
#
#                                  Classification Report
#  0   {'Granny_Smith': {'precision': 0.875, 'recall'...
#  1   {'Granny_Smith': {'precision': 0.9230769230769...
#  2   {'Granny_Smith': {'precision': 0.92, 'recall':...
#  3   {'Granny_Smith': {'precision': 1.0, 'recall': ...
#  4   {'American lobster, Northern lobster, Maine lo...
#  ..                                                ...
#  88  {'Granny_Smith': {'precision': 0.96, 'recall':...
#  89  {'Granny_Smith': {'precision': 0.8888888888888...
#  90  {'Granny_Smith': {'precision': 1.0, 'recall': ...
#  91  {'Granny_Smith': {'precision': 0.8888888888888...
#  92  {'Granny_Smith': {'precision': 0.8888888888888...
#
#  [93 rows x 8 columns],
#                                               model_id          dataset  \
#  0                timm/mobilenetv3_small_100.lamb_in1k  superclass_sign
#  1                               timm/resnet50.a1_in1k  superclass_sign
#  2                           timm/inception_v3.tv_in1k  superclass_sign
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...  superclass_sign
#  4                        timm/efficientnet_b0.ra_in1k  superclass_sign
#  ..                                                ...              ...
#  88                    timm/focalnet_small_lrf.ms_in1k  superclass_sign
#  89                         timm/darknetaa53.c2ns_in1k  superclass_sign
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k  superclass_sign
#  91                          timm/regnetz_c16.ra3_in1k  superclass_sign
#  92                       timm/mobileone_s4.apple_in1k  superclass_sign
#
#      Top-1 Accuracy  Top-5 Accuracy  Precision  Recall  F1-score  \
#  0             0.75            0.88   0.987500    0.75  0.851938
#  1             0.81            0.93   0.975900    0.81  0.885213
#  2             0.81            0.88   0.988095    0.81  0.890097
#  3             0.83            0.96   0.953753    0.83  0.887554
#  4             0.82            0.91   0.975000    0.82  0.890307
#  ..             ...             ...        ...     ...       ...
#  88            0.81            0.95   0.952778    0.81  0.874854
#  89            0.79            0.93   0.986842    0.79  0.876976
#  90            0.85            0.96   0.976984    0.85  0.908810
#  91            0.82            0.96   0.987500    0.82  0.895699
#  92            0.81            0.94   0.975610    0.81  0.885093
#
#                                  Classification Report
#  0   {'ashcan, trash can, garbage can, wastebin, as...
#  1   {'bakery, bakeshop, bakehouse': {'precision': ...
#  2   {'barbershop': {'precision': 0.0, 'recall': 0....
#  3   {'analog clock': {'precision': 0.0, 'recall': ...
#  4   {'barbershop': {'precision': 0.0, 'recall': 0....
#  ..                                                ...
#  88  {'ashcan, trash can, garbage can, wastebin, as...
#  89  {'abacus': {'precision': 0.0, 'recall': 0.0, '...
#  90  {'ashcan, trash can, garbage can, wastebin, as...
#  91  {'bakery, bakeshop, bakehouse': {'precision': ...
#  92  {'analog clock': {'precision': 0.0, 'recall': ...
#
#  [93 rows x 8 columns],
#                                               model_id            dataset  \
#  0                timm/mobilenetv3_small_100.lamb_in1k  superclass_turtle
#  1                               timm/resnet50.a1_in1k  superclass_turtle
#  2                           timm/inception_v3.tv_in1k  superclass_turtle
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...  superclass_turtle
#  4                        timm/efficientnet_b0.ra_in1k  superclass_turtle
#  ..                                                ...                ...
#  88                    timm/focalnet_small_lrf.ms_in1k  superclass_turtle
#  89                         timm/darknetaa53.c2ns_in1k  superclass_turtle
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k  superclass_turtle
#  91                          timm/regnetz_c16.ra3_in1k  superclass_turtle
#  92                       timm/mobileone_s4.apple_in1k  superclass_turtle
#
#      Top-1 Accuracy  Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.572           0.896   0.727786   0.572  0.631660
#  1            0.728           0.956   0.777638   0.728  0.747045
#  2            0.704           0.960   0.765477   0.704  0.727426
#  3            0.768           1.000   0.786142   0.768  0.772425
#  4            0.716           0.956   0.782661   0.716  0.741883
#  ..             ...             ...        ...     ...       ...
#  88           0.768           0.988   0.791787   0.768  0.776078
#  89           0.732           0.976   0.782515   0.732  0.748307
#  90           0.768           0.988   0.799191   0.768  0.779947
#  91           0.740           0.968   0.787593   0.740  0.756119
#  92           0.708           0.960   0.764523   0.708  0.731377
#
#                                  Classification Report
#  0   {'American alligator, Alligator mississipiensi...
#  1   {'box': {'precision': 0.7894736842105263, 'rec...
#  2   {'American alligator, Alligator mississipiensi...
#  3   {'box': {'precision': 0.8301886792452831, 'rec...
#  4   {'African crocodile, Nile crocodile, Crocodylu...
#  ..                                                ...
#  88  {'box': {'precision': 0.8035714285714286, 'rec...
#  89  {'box': {'precision': 0.7678571428571429, 'rec...
#  90  {'book jacket, dust cover, dust jacket, dust w...
#  91  {'box': {'precision': 0.7586206896551724, 'rec...
#  92  {'American alligator, Alligator mississipiensi...
#
#  [93 rows x 8 columns],
#                                               model_id             dataset  \
#  0                timm/mobilenetv3_small_100.lamb_in1k  superclass_vehicle
#  1                               timm/resnet50.a1_in1k  superclass_vehicle
#  2                           timm/inception_v3.tv_in1k  superclass_vehicle
#  3   timm/swinv2_large_window12to16_192to256.ms_in2...  superclass_vehicle
#  4                        timm/efficientnet_b0.ra_in1k  superclass_vehicle
#  ..                                                ...                 ...
#  88                    timm/focalnet_small_lrf.ms_in1k  superclass_vehicle
#  89                         timm/darknetaa53.c2ns_in1k  superclass_vehicle
#  90           timm/tiny_vit_21m_384.dist_in22k_ft_in1k  superclass_vehicle
#  91                          timm/regnetz_c16.ra3_in1k  superclass_vehicle
#  92                       timm/mobileone_s4.apple_in1k  superclass_vehicle
#
#      Top-1 Accuracy  Top-5 Accuracy  Precision  Recall  F1-score  \
#  0            0.668           0.900   0.847267   0.668  0.736165
#  1            0.832           0.964   0.932639   0.832  0.875613
#  2            0.768           0.928   0.888235   0.768  0.812227
#  3            0.892           0.972   0.963866   0.892  0.923861
#  4            0.784           0.952   0.924571   0.784  0.840358
#  ..             ...             ...        ...     ...       ...
#  88           0.840           0.968   0.944253   0.840  0.883331
#  89           0.796           0.964   0.910681   0.796  0.843379
#  90           0.872           0.964   0.950597   0.872  0.904316
#  91           0.860           0.972   0.929915   0.860  0.889916
#  92           0.816           0.944   0.914594   0.816  0.855572
#
#                                  Classification Report
#  0   {'Model T': {'precision': 0.0, 'recall': 0.0, ...
#  1   {'Model T': {'precision': 0.0, 'recall': 0.0, ...
#  2   {'Model T': {'precision': 0.0, 'recall': 0.0, ...
#  3   {'ambulance': {'precision': 0.9523809523809523...
#  4   {'Model T': {'precision': 0.0, 'recall': 0.0, ...
#  ..                                                ...
#  88  {'Model T': {'precision': 0.0, 'recall': 0.0, ...
#  89  {'Model T': {'precision': 0.0, 'recall': 0.0, ...
#  90  {'Model T': {'precision': 0.0, 'recall': 0.0, ...
#  91  {'Model T': {'precision': 0.0, 'recall': 0.0, ...
#  92  {'Model T': {'precision': 0.0, 'recall': 0.0, ...
#
#  [93 rows x 8 columns]]

# %%
evaluation_labels = torch.tensor([
    torch.tensor(df["Top-1 Accuracy"].values).argmax().item()
    for df in evaluation_data
]) 

evaluation_labels.shape
# Out:
# torch.Size([312])

# %%
real_accuracy_matrix = torch.stack([
    torch.tensor(df["Top-1 Accuracy"].values).float()
    for df in evaluation_data
], dim=1)
real_accuracy_matrix = real_accuracy_matrix.T
real_accuracy_matrix.shape
# Out:
# torch.Size([312, 93])

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
model = BaggingClassifier(
    estimator=SVC(probability=True),
    max_samples=1.0,
    max_features=1.0,  
    n_estimators=N_ESTIMATORS,
    bootstrap=False,
    bootstrap_features=True,
    n_jobs=-1,
)
model
# Out:
# BaggingClassifier(bootstrap=False, bootstrap_features=True,
#                   estimator=SVC(probability=True), n_estimators=100, n_jobs=-1)

# %%
pipe_lr = make_pipeline(StandardScaler(), model)
pipe_lr
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('baggingclassifier',
#                  BaggingClassifier(bootstrap=False, bootstrap_features=True,
#                                    estimator=SVC(probability=True),
#                                    n_estimators=100, n_jobs=-1))])

# %%
class Model:
    def __init__(self, model_id, pred_perf, real_perf):
        self.model_id = model_id
        self.pred_perf = pred_perf
        self.real_perf = real_perf

# %%
def dcg_at_k(relevance: torch.Tensor, k: int) -> float:
    """Compute DCG using raw relevance values (assumes higher = better)"""
    rel_k = relevance[:k]
    denom = torch.log2(torch.arange(2, k + 2).float())
    return torch.sum(rel_k / denom)



def NDCG(model_list, k=5, sample_size=1):
    ndcg_scores = []

    for _ in range(sample_size):
        # Get scores
        predicted_scores = torch.tensor([m.pred_perf for m in model_list])
        true_scores = torch.tensor([m.real_perf for m in model_list])

        # Ideal relevance order (ground truth sorted descending)
        _, ideal_indices = torch.sort(true_scores, descending=True)
        ideal_relevance = true_scores[ideal_indices]

        # Predicted relevance order (based on SDS scores)
        _, predicted_indices = torch.sort(predicted_scores, descending=True)
        predicted_relevance = true_scores[predicted_indices]

        # Normalize scores (0 to 1) before computing DCG
        max_val = true_scores.max()
        if max_val > 0:
            predicted_relevance = predicted_relevance / max_val
            ideal_relevance = ideal_relevance / max_val

        dcg = dcg_at_k(predicted_relevance, k)
        idcg = dcg_at_k(ideal_relevance, k)

        ndcg = (dcg / idcg).item() if idcg > 0 else 0.0
        ndcg_scores.append(ndcg)

    return ndcg_scores

def MRR(model_list, sample_size=1):
    mrr = []

    for _ in range(sample_size):
        SDS_scores = torch.tensor([m.pred_perf for m in model_list])
        real_scores = torch.tensor([m.real_perf for m in model_list])

        _, predicted_indices = torch.sort(SDS_scores, descending=True)
        _, ideal_indices = torch.sort(real_scores, descending=True)

        # Find the rank of the best real model in the predicted list
        top_real_model = ideal_indices[0].item()
        rank = (predicted_indices == top_real_model).nonzero(as_tuple=True)[
            0
        ].item() + 1
        mrr.append(1.0 / rank)

    return mrr


def MAP(model_list, k=3, sample_size=1):
    ap_scores = []

    for _ in range(sample_size):
        SDS_scores = torch.tensor([m.pred_perf for m in model_list])
        real_scores = torch.tensor([m.real_perf for m in model_list])

        _, predicted_indices = torch.sort(SDS_scores, descending=True)
        _, ideal_indices = torch.sort(real_scores, descending=True)

        predicted_topk = predicted_indices[:k]
        ideal_topk = set(ideal_indices[:k].tolist())

        hits = 0
        precision_sum = 0.0

        for n, idx in enumerate(predicted_topk):
            if idx.item() in ideal_topk:
                hits += 1
                precision_sum += hits / (n + 1)

        ap = precision_sum / len(ideal_topk) if hits > 0 else 0.0
        ap_scores.append(ap)

    return ap_scores

# %%
from sklearn.model_selection import train_test_split

# %%
X = meta_features.cpu().numpy()
Y = evaluation_labels.cpu().numpy()
X_train, X_test, y_train, y_test, idx_train, idx_test = None, None, None, None, None, None,
for _ in range(100):
    X_train, X_test, y_train, y_test, idx_train, idx_test = train_test_split(
        X, Y, range(len(meta_features)), test_size=0.2
    )

# print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
pipe_lr.fit(X_train, y_train)
prediction_proba = pipe_lr.predict_proba(X_test)
prediction_proba
# Out:
# array([[0.30388727, 0.00766693, 0.0153981 , ..., 0.0182836 , 0.05880346,
#         0.00556569],
#        [0.31442537, 0.00776948, 0.01861366, ..., 0.02000571, 0.0729367 ,
#         0.00695087],
#        [0.31441018, 0.0069152 , 0.01544389, ..., 0.01288722, 0.06467124,
#         0.00780659],
#        ...,
#        [0.27920351, 0.00539938, 0.01537724, ..., 0.01632969, 0.07675068,
#         0.00420905],
#        [0.31437191, 0.0063739 , 0.01845937, ..., 0.01354769, 0.0655178 ,
#         0.01200281],
#        [0.30393202, 0.00579887, 0.01644595, ..., 0.01530357, 0.06507521,
#         0.00959259]], shape=(63, 22))

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
def train_custom_bagging_ensemble(X_train, y_train, n_estimators=N_ESTIMATORS):

    estimators = []
    scaler = StandardScaler().fit(X_train)
    X_train_scaled = scaler.transform(X_train)

    for seed in range(N_ESTIMATORS):
        np.random.seed(seed)
        indices = np.random.choice(len(X_train), len(X_train), replace=True)
        X_sub = X_train_scaled[indices]
        y_sub = y_train[indices]

        clf = SVC(probability=True)
        clf.fit(X_sub, y_sub)
        estimators.append(clf)
    
    return estimators, scaler

# %%
estimators, scaler = train_custom_bagging_ensemble(X_train, y_train)
print(estimators)
print(scaler)
# Out:
# [SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True), SVC(probability=True)]
# StandardScaler()

# %%
def predict_proba_bagging(estimators, scaler, X_test):
    X_test_scaled = scaler.transform(X_test)
    all_probs = []
    
    for clf in estimators:
        proba = clf.predict_proba(X_test_scaled)  # shape: [n_samples, num_classes_seen]
        
        # Map to full class set
        probs_full = np.zeros((X_test.shape[0], NUM_CLASSES))
        for i, cls in enumerate(clf.classes_):
            probs_full[:, cls] = proba[:, i]
        
        all_probs.append(probs_full)
    
    # Average across all estimators
    avg_probs = np.mean(all_probs, axis=0)  # shape: [n_samples, 93]
    return avg_probs

# %%
prediction_proba = predict_proba_bagging(estimators, scaler, X_test)
prediction_proba
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.03191875, 0.00618126,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.09409027, 0.00672574,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.05862413, 0.005344  ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.10232638, 0.00799922,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.05981461, 0.00524195,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.05327512, 0.00557742,
#         0.        ]], shape=(63, 93))

# %%
ndcg5_t, mrr_t, map_t = [], [], []
acc_list = []
for i, task_index in enumerate(idx_test):
    model_list = []

    for model_id in range(NUM_CLASSES):
        pred_perf = float(prediction_proba[i][model_id])
        # print(f"Pred perf: {pred_perf}")
        real_perf = real_accuracy_matrix[task_index][model_id].item()
        # print(f"Real perf: {real_perf}")

        model = Model(model_id=str(model_id), pred_perf=pred_perf, real_perf=real_perf)
        model_list.append(model)

    ndcg5_t.extend(NDCG(model_list, k=5, sample_size=1))
    mrr_t.extend(MRR(model_list, sample_size=1))
    map_t.extend(MAP(model_list, k=3, sample_size=1))

acc = pipe_lr.score(X_test, y_test)
acc_list.append(acc)

# %%
task_idx = 0
sds_scores = prediction_proba[task_idx]
real_scores = real_accuracy_matrix[idx_test[task_idx]]

top_pred = torch.topk(torch.tensor(sds_scores), 5).indices
top_real = torch.topk(real_scores, 5).indices

print("Top predicted models:", top_pred.tolist())
print("Top real models:", top_real.tolist())
# Out:
# Top predicted models: [3, 72, 65, 34, 90]
# Top real models: [72, 15, 3, 34, 62]

# %%
print("acc: ", sum(acc_list) / len(acc_list))
print("ndcg5: ", sum(ndcg5_t) / len(ndcg5_t))
print("mrr: ", sum(mrr_t) / len(mrr_t))
print("map: ", sum(map_t) / len(map_t))
# Out:
# acc:  0.31746031746031744
# ndcg5:  0.9924523915563311
# mrr:  0.5373795904103376
# map:  0.41710758377425067

# %%
print("len(acc_list):", len(acc_list))
print("len(ndcg5_t):", len(ndcg5_t))
print("len(mrr_t):", len(mrr_t))
print("len(map_t):", len(map_t))
# Out:
# len(acc_list): 1
# len(ndcg5_t): 63
# len(mrr_t): 63
# len(map_t): 63

# %%
import pickle

with open("acc_list.pkl", "wb") as f:
    pickle.dump(acc_list, f)

with open("ndcg5_list.pkl", "wb") as f:
    pickle.dump(ndcg5_t, f)

with open("mrr_list.pkl", "wb") as f:
    pickle.dump(mrr_t, f)

with open("map_list.pkl", "wb") as f:
    pickle.dump(map_t, f)

# %%
# Save per-task ranking metrics
results_df = pd.DataFrame({
    "NDCG@5": ndcg5_t,
    "MRR": mrr_t,
    "MAP@3": map_t
})
results_df.to_csv("sds_metrics_per_task.csv", index=False)

# Save overall accuracy separately
overall_df = pd.DataFrame({"Accuracy": [acc_list[0]]})
overall_df.to_csv("overall_accuracy.csv", index=False)

# %%
import collections
counts = collections.Counter(Y)
print("Label distribution:")
for model_id in range(93):
    print(f"Model {model_id}: {counts[model_id]} times")
# Out:
# Label distribution:
# Model 0: 0 times
# Model 1: 0 times
# Model 2: 0 times
# Model 3: 97 times
# Model 4: 0 times
# Model 5: 0 times
# Model 6: 0 times
# Model 7: 0 times
# Model 8: 1 times
# Model 9: 1 times
# Model 10: 0 times
# Model 11: 0 times
# Model 12: 5 times
# Model 13: 0 times
# Model 14: 0 times
# Model 15: 7 times
# Model 16: 0 times
# Model 17: 0 times
# Model 18: 0 times
# Model 19: 1 times
# Model 20: 0 times
# Model 21: 0 times
# Model 22: 2 times
# Model 23: 0 times
# Model 24: 12 times
# Model 25: 0 times
# Model 26: 0 times
# Model 27: 0 times
# Model 28: 0 times
# Model 29: 0 times
# Model 30: 0 times
# Model 31: 3 times
# Model 32: 14 times
# Model 33: 6 times
# Model 34: 13 times
# Model 35: 0 times
# Model 36: 0 times
# Model 37: 1 times
# Model 38: 0 times
# Model 39: 0 times
# Model 40: 1 times
# Model 41: 0 times
# Model 42: 0 times
# Model 43: 0 times
# Model 44: 1 times
# Model 45: 0 times
# Model 46: 0 times
# Model 47: 0 times
# Model 48: 0 times
# Model 49: 0 times
# Model 50: 0 times
# Model 51: 0 times
# Model 52: 0 times
# Model 53: 0 times
# Model 54: 0 times
# Model 55: 0 times
# Model 56: 0 times
# Model 57: 0 times
# Model 58: 0 times
# Model 59: 0 times
# Model 60: 0 times
# Model 61: 0 times
# Model 62: 8 times
# Model 63: 0 times
# Model 64: 0 times
# Model 65: 33 times
# Model 66: 0 times
# Model 67: 0 times
# Model 68: 0 times
# Model 69: 3 times
# Model 70: 0 times
# Model 71: 0 times
# Model 72: 69 times
# Model 73: 0 times
# Model 74: 0 times
# Model 75: 0 times
# Model 76: 0 times
# Model 77: 0 times
# Model 78: 0 times
# Model 79: 0 times
# Model 80: 0 times
# Model 81: 0 times
# Model 82: 2 times
# Model 83: 0 times
# Model 84: 0 times
# Model 85: 0 times
# Model 86: 0 times
# Model 87: 3 times
# Model 88: 6 times
# Model 89: 0 times
# Model 90: 21 times
# Model 91: 2 times
# Model 92: 0 times

# %%
top_models = []
for df in evaluation_data:
    top_model = df["Top-1 Accuracy"].idxmax()
    top_models.append(top_model)

model_counts = collections.Counter(top_models)
for model_id, count in model_counts.most_common():
    print(f"Model {model_id}: {count} times top-1")
# Out:
# Model 3: 97 times top-1
# Model 72: 69 times top-1
# Model 65: 33 times top-1
# Model 90: 21 times top-1
# Model 32: 14 times top-1
# Model 34: 13 times top-1
# Model 24: 12 times top-1
# Model 62: 8 times top-1
# Model 15: 7 times top-1
# Model 33: 6 times top-1
# Model 88: 6 times top-1
# Model 12: 5 times top-1
# Model 69: 3 times top-1
# Model 31: 3 times top-1
# Model 87: 3 times top-1
# Model 91: 2 times top-1
# Model 22: 2 times top-1
# Model 82: 2 times top-1
# Model 19: 1 times top-1
# Model 40: 1 times top-1
# Model 37: 1 times top-1
# Model 8: 1 times top-1
# Model 44: 1 times top-1
# Model 9: 1 times top-1

# %%
import scipy.stats

entropies = []
for probs in prediction_proba:
    entropies.append(scipy.stats.entropy(probs))

print(f"Mean entropy of predicted rankings: {np.mean(entropies):.4f}")
# Out:
# Mean entropy of predicted rankings: 2.0780

# %%
from scipy.spatial.distance import cosine
similarities = []

for i in range(len(prediction_proba)):
    for j in range(i+1, len(prediction_proba)):
        sim = 1 - cosine(prediction_proba[i], prediction_proba[j])
        similarities.append(sim)

print(f"Mean predicted ranking similarity across tasks: {np.mean(similarities):.4f}")
# Out:
# Mean predicted ranking similarity across tasks: 0.9330

# %%
top1_preds = [np.argmax(p) for p in prediction_proba]
top3_sets = [tuple(np.argsort(p)[-3:][::-1]) for p in prediction_proba]

print(f"Unique top-1 predictions: {len(set(top1_preds))}")
print(f"Unique top-3 predictions: {len(set(top3_sets))}")
# Out:
# Unique top-1 predictions: 2
# Unique top-3 predictions: 7
